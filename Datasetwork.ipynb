# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Reading the dataset
df=pd.read_csv("Life Expectancy Data.csv")
df
# Out:
#           Country  Year      Status  Life expectancy   Adult Mortality  \
# 0     Afghanistan  2015  Developing              65.0            263.0
# 1     Afghanistan  2014  Developing              59.9            271.0
# 2     Afghanistan  2013  Developing              59.9            268.0
# 3     Afghanistan  2012  Developing              59.5            272.0
# 4     Afghanistan  2011  Developing              59.2            275.0
# ...           ...   ...         ...               ...              ...
# 2933     Zimbabwe  2004  Developing              44.3            723.0
# 2934     Zimbabwe  2003  Developing              44.5            715.0
# 2935     Zimbabwe  2002  Developing              44.8             73.0
# 2936     Zimbabwe  2001  Developing              45.3            686.0
# 2937     Zimbabwe  2000  Developing              46.0            665.0
#
#       infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2938 entries, 0 to 2937
# Data columns (total 22 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Country                          2938 non-null   object
#  1   Year                             2938 non-null   int64
#  2   Status                           2938 non-null   object
#  3   Life expectancy                  2928 non-null   float64
#  4   Adult Mortality                  2928 non-null   float64
#  5   infant deaths                    2938 non-null   int64
#  6   Alcohol                          2744 non-null   float64
#  7   percentage expenditure           2938 non-null   float64
#  8   Hepatitis B                      2385 non-null   float64
#  9   Measles                          2938 non-null   int64
#  10   BMI                             2904 non-null   float64
#  11  under-five deaths                2938 non-null   int64
# ...

# %%
df.isnull().sum()/df.shape[0]*100
# Out:
# Country                             0.000000
# Year                                0.000000
# Status                              0.000000
# Life expectancy                     0.340368
# Adult Mortality                     0.340368
# infant deaths                       0.000000
# Alcohol                             6.603131
# percentage expenditure              0.000000
# Hepatitis B                        18.822328
# Measles                             0.000000
#  BMI                                1.157250
# under-five deaths                   0.000000
# Polio                               0.646698
# Total expenditure                   7.692308
# Diphtheria                          0.646698
#  HIV/AIDS                           0.000000
# GDP                                15.248468
# Population                         22.191967
#  thinness  1-19 years               1.157250
#  thinness 5-9 years                 1.157250
# Income composition of resources     5.684139
# ...

# %%
df.describe()
# Out:
#               Year  Life expectancy   Adult Mortality  infant deaths  \
# count  2938.000000       2928.000000      2928.000000    2938.000000
# mean   2007.518720         69.224932       164.796448      30.303948
# std       4.613841          9.523867       124.292079     117.926501
# min    2000.000000         36.300000         1.000000       0.000000
# 25%    2004.000000         63.100000        74.000000       0.000000
# 50%    2008.000000         72.100000       144.000000       3.000000
# 75%    2012.000000         75.700000       228.000000      22.000000
# max    2015.000000         89.000000       723.000000    1800.000000
#
#            Alcohol  percentage expenditure  Hepatitis B       Measles   \
# count  2744.000000             2938.000000  2385.000000    2938.000000
# mean      4.602861              738.251295    80.940461    2419.592240
# std       4.052413             1987.914858    25.070016   11467.272489
# ...

# %%
#finding duplicates
df.duplicated().sum()
df
# Out:
#           Country  Year      Status  Life expectancy   Adult Mortality  \
# 0     Afghanistan  2015  Developing              65.0            263.0
# 1     Afghanistan  2014  Developing              59.9            271.0
# 2     Afghanistan  2013  Developing              59.9            268.0
# 3     Afghanistan  2012  Developing              59.5            272.0
# 4     Afghanistan  2011  Developing              59.2            275.0
# ...           ...   ...         ...               ...              ...
# 2933     Zimbabwe  2004  Developing              44.3            723.0
# 2934     Zimbabwe  2003  Developing              44.5            715.0
# 2935     Zimbabwe  2002  Developing              44.8             73.0
# 2936     Zimbabwe  2001  Developing              45.3            686.0
# 2937     Zimbabwe  2000  Developing              46.0            665.0
#
#       infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   \
# ...

# %%
for i in df.select_dtypes(include="object").columns:
    print(df[i].value_counts())
    print('***'*10)
# Out:
# Country
# Afghanistan              16
# Peru                     16
# Nicaragua                16
# Niger                    16
# Nigeria                  16
#                          ..
# Niue                      1
# San Marino                1
# Nauru                     1
# Saint Kitts and Nevis     1
# Dominica                  1
# Name: count, Length: 193, dtype: int64
# ******************************
# Status
# Developing    2426
# Developed      512
# Name: count, dtype: int64
# ******************************

# %%
#EDA
#descriptive statastics
df.describe()
# Out:
#               Year  Life expectancy   Adult Mortality  infant deaths  \
# count  2938.000000       2928.000000      2928.000000    2938.000000
# mean   2007.518720         69.224932       164.796448      30.303948
# std       4.613841          9.523867       124.292079     117.926501
# min    2000.000000         36.300000         1.000000       0.000000
# 25%    2004.000000         63.100000        74.000000       0.000000
# 50%    2008.000000         72.100000       144.000000       3.000000
# 75%    2012.000000         75.700000       228.000000      22.000000
# max    2015.000000         89.000000       723.000000    1800.000000
#
#            Alcohol  percentage expenditure  Hepatitis B       Measles   \
# count  2744.000000             2938.000000  2385.000000    2938.000000
# mean      4.602861              738.251295    80.940461    2419.592240
# std       4.052413             1987.914858    25.070016   11467.272489
# ...

# %%
#TRANSPOSE
df.describe().T
# Out:
#                                   count          mean           std  \
# Year                             2938.0  2.007519e+03  4.613841e+00
# Life expectancy                  2928.0  6.922493e+01  9.523867e+00
# Adult Mortality                  2928.0  1.647964e+02  1.242921e+02
# infant deaths                    2938.0  3.030395e+01  1.179265e+02
# Alcohol                          2744.0  4.602861e+00  4.052413e+00
# percentage expenditure           2938.0  7.382513e+02  1.987915e+03
# Hepatitis B                      2385.0  8.094046e+01  2.507002e+01
# Measles                          2938.0  2.419592e+03  1.146727e+04
#  BMI                             2904.0  3.832125e+01  2.004403e+01
# under-five deaths                2938.0  4.203574e+01  1.604455e+02
# Polio                            2919.0  8.255019e+01  2.342805e+01
# Total expenditure                2712.0  5.938190e+00  2.498320e+00
# Diphtheria                       2919.0  8.232408e+01  2.371691e+01
# ...

# %%
df.describe(include='object')
# Out:
#             Country      Status
# count          2938        2938
# unique          193           2
# top     Afghanistan  Developing
# freq             16        2426

# %%
#Histogram
for i in df.select_dtypes(include='number').columns:
    sns.histplot(data=df,x=i)
    plt.show()

# %%
#Boxplot
for i in df.select_dtypes(include='number').columns:
    sns.boxplot(data=df,x=i)
    plt.show()

# %%
df.select_dtypes(include='number').columns
# Out:
# Index(['Year', 'Life expectancy ', 'Adult Mortality', 'infant deaths',
#        'Alcohol', 'percentage expenditure', 'Hepatitis B', 'Measles ', ' BMI ',
#        'under-five deaths ', 'Polio', 'Total expenditure', 'Diphtheria ',
#        ' HIV/AIDS', 'GDP', 'Population', ' thinness  1-19 years',
#        ' thinness 5-9 years', 'Income composition of resources', 'Schooling'],
#       dtype='object')

# %%
for i in['Year', 'Life expectancy ', 'Adult Mortality', 'infant deaths',
       'Alcohol', 'percentage expenditure', 'Hepatitis B', 'Measles ', ' BMI ',
       'under-five deaths ', 'Polio', 'Total expenditure', 'Diphtheria ',
       ' HIV/AIDS', 'GDP', 'Population', ' thinness  1-19 years',
       ' thinness 5-9 years', 'Income composition of resources', 'Schooling']:
    sns.scatterplot(data=df,x=i,y='Life expectancy ')
    plt.show()

# %%
jj=df.select_dtypes(include='number').corr()
jj
# Out:
#                                      Year  Life expectancy   Adult Mortality  \
# Year                             1.000000          0.170033        -0.079052
# Life expectancy                  0.170033          1.000000        -0.696359
# Adult Mortality                 -0.079052         -0.696359         1.000000
# infant deaths                   -0.037415         -0.196557         0.078756
# Alcohol                         -0.052990          0.404877        -0.195848
# percentage expenditure           0.031400          0.381864        -0.242860
# Hepatitis B                      0.104333          0.256762        -0.162476
# Measles                         -0.082493         -0.157586         0.031176
#  BMI                             0.108974          0.567694        -0.387017
# under-five deaths               -0.042937         -0.222529         0.094146
# Polio                            0.094158          0.465556        -0.274823
# ...

# %%
plt.figure(figsize=(16,16))
sns.heatmap(jj,annot=True)
# Out:
# <Axes: >

# %%
df.isnull().sum()
# Out:
# Country                              0
# Year                                 0
# Status                               0
# Life expectancy                     10
# Adult Mortality                     10
# infant deaths                        0
# Alcohol                            194
# percentage expenditure               0
# Hepatitis B                        553
# Measles                              0
#  BMI                                34
# under-five deaths                    0
# Polio                               19
# Total expenditure                  226
# Diphtheria                          19
#  HIV/AIDS                            0
# GDP                                448
# Population                         652
#  thinness  1-19 years               34
#  thinness 5-9 years                 34
# Income composition of resources    167
# Schooling                          163
# dtype: int64

# %%
df.columns = df.columns.str.strip()

# %%
for i in ["BMI", "Polio", "Income composition of resources"]:
    df[i] = df[i].fillna(df[i].median())

# %%
df.isnull().sum()
# Out:
# Country                              0
# Year                                 0
# Status                               0
# Life expectancy                     10
# Adult Mortality                     10
# infant deaths                        0
# Alcohol                            194
# percentage expenditure               0
# Hepatitis B                        553
# Measles                              0
# BMI                                  0
# under-five deaths                    0
# Polio                                0
# Total expenditure                  226
# Diphtheria                          19
# HIV/AIDS                             0
# GDP                                448
# Population                         652
# thinness  1-19 years                34
# thinness 5-9 years                  34
# Income composition of resources      0
# Schooling                          163
# dtype: int64

# %%
from sklearn.impute import KNNImputer
imputer=KNNImputer()

# %% [raw]
# for i in df.select_dtypes(include='number').columns:
#     df[i]=impute.fit_transform(df[[i]])

# %%
df.isnull().sum()
# Out:
# Country                              0
# Year                                 0
# Status                               0
# Life expectancy                     10
# Adult Mortality                     10
# infant deaths                        0
# Alcohol                            194
# percentage expenditure               0
# Hepatitis B                        553
# Measles                              0
# BMI                                  0
# under-five deaths                    0
# Polio                                0
# Total expenditure                  226
# Diphtheria                          19
# HIV/AIDS                             0
# GDP                                448
# Population                         652
# thinness  1-19 years                34
# thinness 5-9 years                  34
# Income composition of resources      0
# Schooling                          163
# dtype: int64

# %%
def wisker(col):
   q1,q3=np.percentile(col,[25,75])
   iqr=q3-q1
   lw=q1-1.5*iqr
   uw=q3+1.5*iqr
   return lw,uw

# %%
wisker(df['GDP'])
# Out:
# (nan, nan)

# %%
def wisker(col):
    for i in ['GDP', 'Total expenditure', 'thinness 1-19 years']:
        lw, uw = whisker(df[i])
        df[i] = np.where(df[i] < lw, lw, df[i])
        df[i] = np.where(df[i] > uw, uw, df[i])

# %%
data = {'GDP': [1, 2, 3], 'Total expenditure': [4, 5, 6], 'thinness 1-19 years': [7, 8, 9]}
df = pd.DataFrame(data)
for i in ['GDP', 'Total expenditure', 'thinness 1-19 years']:
    if i in df.columns:
        sns.barplot(x=df[i])
        plt.show()
    else:
        print(f"Column '{i}' not found.")

# %%
print(df.columns)
# Out:
# Index(['GDP', 'Total expenditure', 'thinness 1-19 years'], dtype='object')

# %%
df.columns = df.columns.str.strip()

# %%
print('Country' in df.columns) 
print('Status' in df.columns)
# Out:
# False
# False

# %%
print(df.head())
# Out:
#    GDP  Total expenditure  thinness 1-19 years
# 0    1                  4                    7
# 1    2                  5                    8
# 2    3                  6                    9

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   GDP                  3 non-null      int64
#  1   Total expenditure    3 non-null      int64
#  2   thinness 1-19 years  3 non-null      int64
# dtypes: int64(3)
# memory usage: 204.0 bytes
# None

# %%
df.rename(columns=lambda x: x.strip(), inplace=True)

# %%
print(df.columns.tolist())
# Out:
# ['GDP', 'Total expenditure', 'thinness 1-19 years']

# %%
df.columns = df.columns.str.strip()  # Removes leading/trailing spaces
df.columns = df.columns.str.lower() # Converts all column names to lowercase
print(df.columns.tolist())
# Out:
# ['gdp', 'total expenditure', 'thinness 1-19 years']

# %%
df.columns = df.columns.str.strip()
print(df.columns.tolist())
# Out:
# ['Country', 'Year', 'Status', 'Life expectancy', 'Adult Mortality', 'infant deaths', 'Alcohol', 'percentage expenditure', 'Hepatitis B', 'Measles', 'BMI', 'under-five deaths', 'Polio', 'Total expenditure', 'Diphtheria', 'HIV/AIDS', 'GDP', 'Population', 'thinness  1-19 years', 'thinness 5-9 years', 'Income composition of resources', 'Schooling']

# %%
df.columns = df.columns.str.strip().str.lower()
available_columns = [col for col in ['country', 'status'] if col in df.columns]
df = pd.get_dummies(df, columns=available_columns, drop_first=True)

# %%
df.columns = df.columns.str.strip().str.lower()
available_columns = [col for col in ['country', 'status'] if col in df.columns]
df = pd.get_dummies(df, columns=available_columns, drop_first=True)
print(df.head())
# Out:
#    year  life expectancy  adult mortality  infant deaths  alcohol  \
# 0  2015             65.0            263.0             62     0.01
# 1  2014             59.9            271.0             64     0.01
# 2  2013             59.9            268.0             66     0.01
# 3  2012             59.5            272.0             69     0.01
# 4  2011             59.2            275.0             71     0.01
#
#    percentage expenditure  hepatitis b  measles   bmi  under-five deaths  ...  \
# 0               71.279624         65.0     1154  19.1                 83  ...
# 1               73.523582         62.0      492  18.6                 86  ...
# 2               73.219243         64.0      430  18.1                 89  ...
# 3               78.184215         67.0     2787  17.6                 93  ...
# 4                7.097109         68.0     3013  17.2                 97  ...
#
#    country_united states of america  country_uruguay  country_uzbekistan  \
# ...

# %%
df.T
# Out:
#                     0      1      2      3      4      5      6      7     \
# year                2015   2014   2013   2012   2011   2010   2009   2008
# life_expectancy     65.0   59.9   59.9   59.5   59.2   58.8   58.6   58.1
# adult_mortality    263.0  271.0  268.0  272.0  275.0  279.0  281.0  287.0
# infant_deaths         62     64     66     69     71     74     77     80
# alcohol             0.01   0.01   0.01   0.01   0.01   0.01   0.01   0.03
# ...                  ...    ...    ...    ...    ...    ...    ...    ...
# country_viet_nam   False  False  False  False  False  False  False  False
# country_yemen      False  False  False  False  False  False  False  False
# country_zambia     False  False  False  False  False  False  False  False
# country_zimbabwe   False  False  False  False  False  False  False  False
# status_developing   True   True   True   True   True   True   True   True
#
#                     8      9     ...   2928   2929   2930   2931   2932  \
# ...

# %%
for col in df.columns:
    print(col)
# Out:
# year
# life_expectancy
# adult_mortality
# infant_deaths
# alcohol
# percentage_expenditure
# hepatitis_b
# measles
# bmi
# underfive_deaths
# polio
# total_expenditure
# diphtheria
# hivaids
# gdp
# population
# thinness__119_years
# thinness_59_years
# income_composition_of_resources
# schooling
# country_albania
# country_algeria
# country_angola
# country_antigua_and_barbuda
# country_argentina
# country_armenia
# country_australia
# country_austria
# country_azerbaijan
# country_bahamas
# country_bahrain
# country_bangladesh
# country_barbados
# country_belarus
# country_belgium
# country_belize
# country_benin
# country_bhutan
# country_bolivia_plurinational_state_of
# country_bosnia_and_herzegovina
# country_botswana
# country_brazil
# country_brunei_darussalam
# country_bulgaria
# country_burkina_faso
# country_burundi
# country_cabo_verde
# country_cambodia
# country_cameroon
# country_canada
# country_central_african_republic
# country_chad
# country_chile
# country_china
# ...

# %%
vertical_cols = pd.DataFrame(df.columns, columns=['Columns'])
print(vertical_cols)
# Out:
#                Columns
# 0                 year
# 1      life_expectancy
# 2      adult_mortality
# 3        infant_deaths
# 4              alcohol
# ..                 ...
# 208   country_viet_nam
# 209      country_yemen
# 210     country_zambia
# 211   country_zimbabwe
# 212  status_developing
#
# [213 rows x 1 columns]
